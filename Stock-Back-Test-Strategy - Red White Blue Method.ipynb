# %%
# Description :
# This pogram is designed to predict a stock of your choosing with an Recurrent Neural Network called Long Short Term Memory
# (LSTM).  You are able to put in an amount of time to track of your choosing (100 days, 52 week, etc.)
#
#

# %%
# IMPORT DATA SCIENCE LIBRARIES
import numpy as np
import pandas as pd
from datetime import datetime
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt 
import seaborn as sns
import yfinance as yf
# %matplotlib inline

# %%
# ADVANCED PLOTING LIBRARIES
from plotly import __version__
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Use cufflinks offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# New Yahoo Finance workaround
yf.pdr_override()

# %%
# Stock LOOKUP
stock = input('Enter a stock ticker symbol: ')
print(stock)
# Out:
# Enter a stock ticker symbol: KR
# KR

# %%
StockStart = '2018-07-01'
StockEnd = datetime.today().strftime('%Y-%m-%d')

# %%
df = pdr.get_data_yahoo(stock,start=StockStart,end=StockEnd)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-07-16  33.900002  34.310001  33.639999  33.730000  33.730000   7005400
# 2020-07-17  33.849998  34.180000  33.779999  33.849998  33.849998   6167900
# 2020-07-20  33.799999  34.160000  33.619999  34.150002  34.150002   8063200
# 2020-07-21  34.360001  35.580002  34.340000  34.790001  34.790001  11880800
# 2020-07-22  34.900002  35.160000  34.580002  35.160000  35.160000   6464200

# %%
# MAKE 50 DAY MOVING AVERAGE
ma = 50
smaString = 'SMA_'+str(ma)
df[smaString] = df['Adj Close'].rolling(window=ma).mean()

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-07-02  28.400000  28.520000  27.860001  28.219999  27.039478  9545800
# 2018-07-03  28.309999  28.940001  28.309999  28.700001  27.499399  4641300
# 2018-07-05  28.809999  29.020000  28.440001  28.600000  27.403580  8165500
# 2018-07-06  28.580000  29.230000  28.580000  29.120001  27.901829  6987800
# 2018-07-09  29.070000  29.180000  28.660000  28.750000  27.547306  5523500
#
#             SMA_50
# Date
# 2018-07-02     NaN
# 2018-07-03     NaN
# 2018-07-05     NaN
# 2018-07-06     NaN
# 2018-07-09     NaN

# %%
df.iloc[48:50]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-09-10  32.119999  32.150002  31.629999  31.750000  30.564970  10614100
# 2018-09-11  31.830000  32.080002  31.370001  31.389999  30.218405  14372000
#
#                SMA_50
# Date
# 2018-09-10        NaN
# 2018-09-11  28.688762

# %%
df.iloc[(ma-2):51]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-09-10  32.119999  32.150002  31.629999  31.750000  30.564970  10614100
# 2018-09-11  31.830000  32.080002  31.370001  31.389999  30.218405  14372000
# 2018-09-12  31.500000  31.830000  31.090000  31.730000  30.545715  11846000
#
#                SMA_50
# Date
# 2018-09-10        NaN
# 2018-09-11  28.688762
# 2018-09-12  28.758887

# %%
# BECAUSE THE FIRST 50 DAYS IS OUT OF RANGE FOR A 50 DAY MOVING AVERAGE
# WE TRIM THE DATAFRAME TO REMOVE THE MA VALUE
df = df.iloc[(ma-1):]

# %%
# NOW OUR DATAFRAME SHOULD START WITH A SMA_50
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-09-11  31.830000  32.080002  31.370001  31.389999  30.218405  14372000
# 2018-09-12  31.500000  31.830000  31.090000  31.730000  30.545715  11846000
# 2018-09-13  28.610001  29.180000  28.299999  28.580000  27.513287  32474400
# 2018-09-14  28.600000  28.610001  27.760000  27.799999  26.762396  18729600
# 2018-09-17  27.750000  28.980000  27.540001  28.840000  27.763580  16749800
#
#                SMA_50
# Date
# 2018-09-11  28.688762
# 2018-09-12  28.758887
# 2018-09-13  28.759165
# 2018-09-14  28.746341
# 2018-09-17  28.743576

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  469.000000  469.000000  469.000000  469.000000  469.000000
# mean    27.696269   28.082324   27.335331   27.713689   27.205106
# std      3.369493    3.491581    3.273500    3.377143    3.483575
# min     20.790001   21.000000   20.700001   20.820000   20.342707
# 25%     24.889999   25.120001   24.530001   24.840000   24.391006
# 50%     28.070000   28.370001   27.760000   28.080000   27.365824
# 75%     29.799999   30.340000   29.420000   29.760000   29.043940
# max     35.750000   36.840000   34.580002   35.160000   35.160000
#
#              Volume      SMA_50
# count  4.690000e+02  469.000000
# mean   9.232672e+06   27.004764
# std    5.258081e+06    2.984168
# min    1.641100e+06   21.718111
# 25%    5.882200e+06   24.375759
# 50%    7.809900e+06   27.545881
# 75%    1.077280e+07   28.706865
# max    4.542470e+07   32.959051

# %%
# Check to see if the adj close for each day is above of below the moving average
# Check to see if Date is index row
df.index
# Out:
# DatetimeIndex(['2018-09-11', '2018-09-12', '2018-09-13', '2018-09-14',
#                '2018-09-17', '2018-09-18', '2018-09-19', '2018-09-20',
#                '2018-09-21', '2018-09-24',
#                ...
#                '2020-07-09', '2020-07-10', '2020-07-13', '2020-07-14',
#                '2020-07-15', '2020-07-16', '2020-07-17', '2020-07-20',
#                '2020-07-21', '2020-07-22'],
#               dtype='datetime64[ns]', name='Date', length=469, freq=None)

# %%
# ITERATE THROUGH DAYS TO SEE IF THE ADJ CLOSE IS HIGHER THAN SMA_50
numH = 0
numC = 0
for i in df.index:
    
    if(df['Adj Close'][i]>df[smaString][i]):
        numH += 1
        print('Adj Close is Higher')
    else:
        numC += 1
        print('SMA_50 is Higher')
print('Adj Close was higher '+str(numH)+' times')
print('SMA_50 was higher '+str(numC)+' times')
# Out:
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# SMA_50 is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close is Higher
# Adj Close was higher 272 times
# SMA_50 was higher 197 times

# %%
#ADD EMAS TO THE DF
# CHOOSE THE Exponential Moving Averages TO USE
emasUsed = [3,5,8,10,12,15,30,35,40,45,50,60]

for q in emasUsed:
    ema = q

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-09-11  31.830000  32.080002  31.370001  31.389999  30.218405  14372000
# 2018-09-12  31.500000  31.830000  31.090000  31.730000  30.545715  11846000
# 2018-09-13  28.610001  29.180000  28.299999  28.580000  27.513287  32474400
# 2018-09-14  28.600000  28.610001  27.760000  27.799999  26.762396  18729600
# 2018-09-17  27.750000  28.980000  27.540001  28.840000  27.763580  16749800
#
#                SMA_50  EMA_3  EMA_5  EMA_8  EMA_10  EMA_12  EMA_15  EMA_30  \
# Date
# 2018-09-11  28.688762  30.22  30.22  30.22   30.22   30.22   30.22   30.22
# 2018-09-12  28.758887  30.38  30.33  30.29   30.28   30.27   30.26   30.24
# 2018-09-13  28.759165  28.95  29.39  29.67   29.78   29.84   29.92   30.06
# 2018-09-14  28.746341  27.86  28.51  29.03   29.23   29.37   29.52   29.85
# 2018-09-17  28.743576  27.81  28.26  28.75   28.96   29.12   29.30   29.72
#
#             EMA_35  EMA_40  EMA_45  EMA_50  EMA_60
# Date
# 2018-09-11   30.22   30.22   30.22   30.22   30.22
# 2018-09-12   30.24   30.23   30.23   30.23   30.23
# 2018-09-13   30.09   30.10   30.11   30.12   30.14
# 2018-09-14   29.90   29.94   29.97   29.99   30.03
# 2018-09-17   29.78   29.83   29.87   29.91   29.96

# %%
# CHECK whether or not it's a red-white-blue pattern at each date with FOR LOOP

pos = 0
num = 0
percent_change = []

for i in df.index:
    #minimum of short term emas
    cmin = min(df['EMA_3'][i],df['EMA_5'][i],df['EMA_8'][i],df['EMA_10'][i],df['EMA_12'][i],df['EMA_15'][i])
    #maximum of long term emas
    cmax = max(df['EMA_30'][i],df['EMA_35'][i],df['EMA_40'][i],df['EMA_45'][i],df['EMA_50'][i],df['EMA_60'][i])
    # Adj Closing Value
    close = df['Adj Close'][i]
    
    if (cmin>cmax):
        print('Red White Blue')
        if (pos==0):
            bp=close
            pos=1
            print('Buying now at  '+str(bp))
    elif(cmin<cmax):
        print('Blue White Red')
        if (pos==1):
            pos=0
            sp=close
            print('Selling now at '+str(sp))
            pc=(sp/bp-1)*100
            percent_change.append(pc)
    if(num==df['Adj Close'].count()-1 and pos==1):
        pos=0
        sp=close
        print('Selling now at '+str(sp))
        pc = (sp/bp-1)*100
        precent_change.append(pc)
        
    num +=1
    
print(percent_change)
# Out:
# Red White Blue
# Buying now at  30.54571533203125
# Blue White Red
# Selling now at 27.513286590576172
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  30.17989730834961
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 28.593904495239258
# Red White Blue
# Buying now at  29.04839324951172
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 27.694604873657227
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  28.71337127685547
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 27.63479995727539
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  23.289033889770508
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 24.391006469726562
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  24.873119354248047
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 27.861665725708008
# Red White Blue
# Buying now at  28.119003295898438
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 27.168838500976562
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  28.396135330200195
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 27.998010635375977
# Red White Blue
# Buying now at  29.540739059448242
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 27.80890464782715
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  31.451730728149414
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 31.760000228881836
# Red White Blue
# Buying now at  32.29999923706055
# Blue White Red
# Selling now at 32.119998931884766
# Red White Blue
# Buying now at  32.369998931884766
# Blue White Red
# Selling now at 31.3700008392334
# Red White Blue
# Buying now at  33.279998779296875
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at 32.08000183105469
# Blue White Red
# Red White Blue
# Buying now at  32.810001373291016
# Blue White Red
# Selling now at 31.809999465942383
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at  32.779998779296875
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Red White Blue
# Selling now at 35.15999984741211
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-3093c3401c72> in <module>
#      32         print('Selling now at '+str(sp))
#      33         pc = (sp/bp-1)*100
# ---> 34         precent_change.append(pc)
#      35
#      36     num +=1
#
# NameError: name 'precent_change' is not defined

# %%
# MAKE A BUNCH OF VARIABLES
gains = 0  # gains
ng = 0     # number of gains
losses=0   # losses
nl = 0     # number of losses
totalR = 1 # Total Returns
ratio = 0

for i in percent_change:
    if(i>0):
        gains+=i
        ng+=1
    else:
        losses+=i
        nl+=1
    totalR = totalR*((i/100)+1)

totalR = round((totalR-1)*100,2)

#Avg Gain, Avg Loss, win/loss ratio
if(ng>0):
    avgGain=gains/ng
    maxR=str(max(percent_change))
else:
    avgGain=0
    maxR="undefined"

if(nl>0):
    avgLoss=losses/nl
    maxL=str(min(percent_change))
    ratio=str(-avgGain/avgLoss)
else:
    avgLoss=0
    maxL="undefined"
    ratio="inf"

if(ng>0 or nl>0):
    battingAvg=ng/(ng+nl)
else:
    battingAvg=0

print()
print("Results for "+ stock +" going back to "+str(df.index[0])+", Sample size: "+str(ng+nl)+" trades")
print("EMAs used: "+str(emasUsed))
print("Batting Avg: "+ str(battingAvg))
print("Gain/loss ratio: "+ ratio)
print("Average Gain: "+ str(avgGain))
print("Average Loss: "+ str(avgLoss))
print("Max Return: "+ maxR)
print("Max Loss: "+ maxL)
print("Total return over "+str(ng+nl)+ " trades: "+ str(totalR)+"%" )
#print("Example return Simulating "+str(n)+ " trades: "+ str(nReturn)+"%" )
print()

# %%
df_avgs = df.drop(['High','Open','Low','Close','Volume'], axis=1)

# %%
df_avgs.head()
# Out:
#             Adj Close     SMA_50  EMA_3  EMA_5  EMA_8  EMA_10  EMA_12  EMA_15  \
# Date
# 2018-09-11  30.218405  28.688762  30.22  30.22  30.22   30.22   30.22   30.22
# 2018-09-12  30.545715  28.758887  30.38  30.33  30.29   30.28   30.27   30.26
# 2018-09-13  27.513287  28.759165  28.95  29.39  29.67   29.78   29.84   29.92
# 2018-09-14  26.762396  28.746341  27.86  28.51  29.03   29.23   29.37   29.52
# 2018-09-17  27.763580  28.743576  27.81  28.26  28.75   28.96   29.12   29.30
#
#             EMA_30  EMA_35  EMA_40  EMA_45  EMA_50  EMA_60
# Date
# 2018-09-11   30.22   30.22   30.22   30.22   30.22   30.22
# 2018-09-12   30.24   30.24   30.23   30.23   30.23   30.23
# 2018-09-13   30.06   30.09   30.10   30.11   30.12   30.14
# 2018-09-14   29.85   29.90   29.94   29.97   29.99   30.03
# 2018-09-17   29.72   29.78   29.83   29.87   29.91   29.96

# %%
plt.figure(figsize=(14,10))
plt.plot(df['Adj Close'],'g')
plt.plot(df['EMA_3'],'r')
plt.plot(df['EMA_5'],'r')
plt.plot(df['EMA_8'],'r')
plt.plot(df['EMA_10'],'r')
plt.plot(df['EMA_12'],'r')
plt.plot(df['EMA_15'],'r')
plt.plot(df['EMA_30'],'b')
plt.plot(df['EMA_35'],'b')
plt.plot(df['EMA_40'],'b')
plt.plot(df['EMA_45'],'b')
plt.plot(df['EMA_50'],'b')
plt.plot(df['EMA_60'],'b')

plt.title('Adj. Close and EMA Prices')
plt.xlabel('Date',fontsize=16)
plt.ylabel('Price USD', fontsize=16)
plt.legend(df_avgs.columns.values, loc = 'lower left')

# %%
plt.figure(figsize=(4,8))
df_avgs.iplot()
# Out:
# <div>
#
#
#             <div id="268fd603-d5c1-4d06-a792-cd89d2203e72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("268fd603-d5c1-4d06-a792-cd89d2203e72")) {
#                     Plotly.newPlot(
#                         '268fd603-d5c1-4d06-a792-cd89d2203e72',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Adj Close", "text": "", "type": "scatter", "x": ["2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-21", "2018-09-24", "2018-09-25", "2018-09-26", "2018-09-27", "2018-09-28", "2018-10-01", "2018-10-02", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-12", "2018-10-15", "2018-10-16", "2018-10-17", "2018-10-18", "2018-10-19", "2018-10-22", "2018-10-23", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-29", "2018-10-30", "2018-10-31", "2018-11-01", "2018-11-02", "2018-11-05", "2018-11-06", "2018-11-07", "2018-11-08", "2018-11-09", "2018-11-12", "2018-11-13", "2018-11-14", "2018-11-15", "2018-11-16", "2018-11-19", "2018-11-20", "2018-11-21", "2018-11-23", "2018-11-26", "2018-11-27", "2018-11-28", "2018-11-29", "2018-11-30", "2018-12-03", "2018-12-04", "2018-12-06", "2018-12-07", "2018-12-10", "2018-12-11", "2018-12-12", "2018-12-13", "2018-12-14", "2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-24", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-31", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-05", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-07", "2019-10-08", "2019-10- ...
